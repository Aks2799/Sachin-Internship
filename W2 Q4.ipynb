# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# The attributes which you have to scrape is ticked marked in the below image.
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands andmore” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this pageyou can scrap the
# required data as usual.
# ASSIGNMENT 2
# 4. After scraping data from the first page, go to the “Next” Button at the bottom ofthe page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100 sunglasses.

# %%
import selenium
from selenium import webdriver
import pandas as dd
import warnings
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome(r'C:/Users/SACHIN/Downloads/chromedriver_win32/chromedriver.exe')

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'http://www.flipkart.com/'
driver.get(url)

# %%
search_product = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search_product
search_product.send_keys("sunglasses")

# %%
search = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# %%
search
search.click()

# %%
product = driver.find_elements_by_class_name("_2WkVRV")
product[0:40]
prd = []
for i in range(len(product)):
     prd.append(product[i].text)
prd[0:40]
# Out:
# ['RESIST EYEWEAR',
#  'VINCENT CHASE',
#  'SRPM',
#  'SUNBEE',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'DEIXELS',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'New Specs',
#  'Lee Topper',
#  'VINCENT CHASE',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'PIRASO',
#  'Singco India',
#  'GANSTA',
#  'kingsunglasses',
#  'SRPM',
#  'VINCENT CHASE',
#  'New Specs',
#  'kingsunglasses',
#  'hipe',
#  'VINCENT CHASE',
#  'SUNBEE',
#  'SRPM',
#  'kingsunglasses',
#  'ROZZETTA CRAFT',
#  'Singco India',
#  'ROZZETTA CRAFT',
#  'Silver Kartz',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Lee Topper',
#  'kingsunglasses',
#  'VINCENT CHASE',
#  'PHENOMENAL',
#  'Elligator',
#  'PIRASO',
#  'VINCENT CHASE']

# %%
brand = driver.find_elements_by_class_name("IRpwTa")
brand[0:40]
brd = []
for i in range(len(brand)):
     brd.append(brand[i].text)
brd[0:40]
# Out:
# ['Toughened Glass Lens, UV Protection, Riding Glasses Way...',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection, Polarized Wayfarer Sunglasses (Free Size...',
#  'Polarized, Night Vision, Riding Glasses Sports, Wrap-ar...',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Aviator, Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Riding Glasses Wrap-around Sunglasses (Free Size)',
#  'by Lenskart UV Protection Aviator Sunglasses (53)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection, Riding Glasses, Others Aviator, Wayfarer...',
#  'UV Protection, Riding Glasses Wayfarer Sunglasses (53)',
# ...

# %%
price = driver.find_elements_by_class_name("_30jeq3")
price[0:40]
prc = []
for i in range(len(price)):
     prc.append(price[i].text)
prc[0:40]
# Out:
# ['₹1,079',
#  '₹949',
#  '₹198',
#  '₹253',
#  '₹474',
#  '₹258',
#  '₹229',
#  '₹426',
#  '₹229',
#  '₹232',
#  '₹275',
#  '₹899',
#  '₹165',
#  '₹719',
#  '₹250',
#  '₹203',
#  '₹198',
#  '₹184',
#  '₹178',
#  '₹999',
#  '₹155',
#  '₹239',
#  '₹258',
#  '₹980',
#  '₹284',
#  '₹220',
#  '₹289',
#  '₹426',
#  '₹219',
#  '₹474',
#  '₹246',
#  '₹759',
#  '₹379',
#  '₹199',
#  '₹186',
#  '₹748',
#  '₹289',
#  '₹189',
#  '₹349',
#  '₹799']

# %%
discount = driver.find_elements_by_class_name("_3Ay6Sb")
discount[0:40]
disc = []
for i in range(len(discount)):
     disc.append(discount[i].text)
disc[0:40]
# Out:
# ['78% off',
#  '52% off',
#  '84% off',
#  '80% off',
#  '76% off',
#  '89% off',
#  '80% off',
#  '78% off',
#  '85% off',
#  '91% off',
#  '88% off',
#  '55% off',
#  '90% off',
#  '10% off',
#  '84% off',
#  '70% off',
#  '88% off',
#  '84% off',
#  '82% off',
#  '50% off',
#  '88% off',
#  '88% off',
#  '86% off',
#  '50% off',
#  '83% off',
#  '77% off',
#  '81% off',
#  '80% off',
#  '85% off',
#  '78% off',
#  '83% off',
#  '62% off',
#  '74% off',
#  '80% off',
#  '81% off',
#  '62% off',
#  '71% off',
#  '81% off',
#  '86% off',
#  '60% off']

# %%
prdts = dd.DataFrame()
prdts["Product Name"] = prd
prdts["Description"] = brd
prdts
# Out:
#          Product Name                                        Description
# 0      RESIST EYEWEAR  Toughened Glass Lens, UV Protection, Riding Gl...
# 1       VINCENT CHASE             UV Protection Wayfarer Sunglasses (55)
# 2                SRPM             UV Protection Wayfarer Sunglasses (50)
# 3              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 4      ROZZETTA CRAFT  Polarized, Night Vision, Riding Glasses Sports...
# 5           Elligator                UV Protection Round Sunglasses (54)
# 6             DEIXELS  UV Protection Aviator, Wayfarer Sunglasses (Fr...
# 7      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 8              PIRASO              UV Protection Aviator Sunglasses (54)
# 9           New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 10         Lee Topper  Riding Glasses Wrap-around Sunglasses (Free Size)
# 11      VINCENT CHASE  by Lenskart UV Protection Aviator Sunglasses (53)
# ...

# %%
nxt_page=driver.find_element_by_class_name("_1LKTO3")
nxt_page
nxt_page.click()

# %%
product = driver.find_elements_by_class_name("_2WkVRV")
product[1:80]
prd = []
for i in range(len(product)):
     prd.append(product[i].text)
prd[1:80]
# Out:
# ['PHENOMENAL',
#  'PIRASO',
#  'VINCENT CHASE',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'GANSTA',
#  'VINCENT CHASE',
#  'NuVew',
#  'New Specs',
#  'PIRASO',
#  'Sewell',
#  'Fastrack',
#  'Fastrack',
#  'ROYAL SON',
#  'ROYAL SON',
#  'New Specs',
#  'SHAAH COLLECTIONS',
#  'Fastrack',
#  'VINCENT CHASE',
#  'Silver Kartz',
#  'Elligator',
#  'kingsunglasses',
#  'ROZZETTA CRAFT',
#  'SUNBEE',
#  'hipe',
#  'GANSTA',
#  'ROYAL SON',
#  'kingsunglasses',
#  'ROYAL SON',
#  'PHENOMENAL',
#  'ROYAL SON',
#  'hipe',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'VINCENT CHASE',
#  'SHAAH COLLECTIONS',
#  'PIRASO',
#  'DEIXELS',
#  'VINCENT CHASE']

# %%
brand = driver.find_elements_by_class_name("IRpwTa")
brand[1:80]
brd = []
for i in range(len(brand)):
     brd.append(brand[i].text)
brd[1:80]
# Out:
# ['UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (32)',
#  'by Lenskart Polarized, UV Protection Round Sunglasses (...',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection Round Sunglasses (55)',
#  'UV Protection Aviator Sunglasses (57)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'UV Protection Sports Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Polarized Butterfly Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'Mirrored Aviator Sunglasses (55)',
#  'Polarized, UV Protection Round Sunglasses (52)',
#  'Mirrored, UV Protection, Riding Glasses, Others Round S...',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (55)',
# ...

# %%
price = driver.find_elements_by_class_name("_30jeq3")
price[0:40]
prc = []
for i in range(len(price)):
     prc.append(price[i].text)
prc[0:40]
# Out:
# ['₹198',
#  '₹328',
#  '₹225',
#  '₹999',
#  '₹379',
#  '₹881',
#  '₹199',
#  '₹759',
#  '₹327',
#  '₹183',
#  '₹250',
#  '₹649',
#  '₹541',
#  '₹563',
#  '₹379',
#  '₹759',
#  '₹263',
#  '₹181',
#  '₹639',
#  '₹999',
#  '₹255',
#  '₹176',
#  '₹180',
#  '₹399',
#  '₹230',
#  '₹209',
#  '₹284',
#  '₹699',
#  '₹258',
#  '₹379',
#  '₹317',
#  '₹599',
#  '₹179',
#  '₹199',
#  '₹307',
#  '₹799',
#  '₹284',
#  '₹299',
#  '₹229',
#  '₹799']

# %%
discount = driver.find_elements_by_class_name("_3Ay6Sb")
discount[0:40]
disc = []
for i in range(len(discount)):
     disc.append(discount[i].text)
disc[0:40]
# Out:
# ['80% off',
#  '83% off',
#  '85% off',
#  '50% off',
#  '81% off',
#  '11% off',
#  '90% off',
#  '62% off',
#  '73% off',
#  '88% off',
#  '84% off',
#  '67% off',
#  '32% off',
#  '29% off',
#  '74% off',
#  '62% off',
#  '81% off',
#  '81% off',
#  '20% off',
#  '50% off',
#  '78% off',
#  '88% off',
#  '83% off',
#  '85% off',
#  '82% off',
#  '79% off',
#  '85% off',
#  '65% off',
#  '87% off',
#  '74% off',
#  '84% off',
#  '70% off',
#  '87% off',
#  '80% off',
#  '84% off',
#  '68% off',
#  '83% off',
#  '81% off',
#  '54% off',
#  '60% off']

# %%
prdts = dd.DataFrame()
prdts["Product Name"] = prd
prdts["Description"] = brd
prdts
# Out:
#          Product Name                                        Description
# 0                hipe  UV Protection, Gradient, Mirrored, Riding Glas...
# 1          PHENOMENAL  UV Protection Retro Square Sunglasses (Free Size)
# 2              PIRASO             UV Protection Wayfarer Sunglasses (32)
# 3       VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...
# 4      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 5            Fastrack                UV Protection Round Sunglasses (55)
# 6              GANSTA              UV Protection Aviator Sunglasses (57)
# 7       VINCENT CHASE             UV Protection Wayfarer Sunglasses (55)
# 8               NuVew               UV Protection Sports Sunglasses (62)
# 9           New Specs       UV Protection Aviator Sunglasses (Free Size)
# 10             PIRASO              UV Protection Aviator Sunglasses (54)
# 11             Sewell         Polarized Butterfly Sunglasses (Free Size)
# ...
