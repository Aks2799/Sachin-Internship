# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
#Write a python program to display all the header tags from wikipedia.org
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>

# %%
# Download IMDB's Top 100 movies data
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
# 89 - Star Wars: Episode VI - Return of the Jedi (1983) - Starring: Richard Marquand (dir.), Mark Hamill, Harrison Ford
# 90 - Reservoir Dogs (1992) - Starring: Quentin Tarantino (dir.), Harvey Keitel, Tim Roth
# 91 - Eternal Sunshine of the Spotless Mind (2004) - Starring: Michel Gondry (dir.), Jim Carrey, Kate Winslet
# 92 - 2001: A Space Odyssey (1968) - Starring: Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood
# 93 - Citizen Kane (1941) - Starring: Orson Welles (dir.), Orson Welles, Joseph Cotten
# 94 - Tengoku to jigoku (1963) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada
# 95 - Lawrence of Arabia (1962) - Starring: David Lean (dir.), Peter O'Toole, Alec Guinness
# 96 - M - Eine Stadt sucht einen Mörder (1931) - Starring: Fritz Lang (dir.), Peter Lorre, Ellen Widmann
# 97 - Capharnaüm (2018) - Starring: Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw
# 98 - North by Northwest (1959) - Starring: Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint
# 99 - Jagten (2012) - Starring: Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen
# 10 -  Vertigo (1958) - Starring: Alfred Hitchcock (dir.), James Stewart, Kim Novak

# %%
# Download IMDB's Top 100 movies data
url = 'https://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup2 = BeautifulSoup(response.text, 'lxml')

movies = soup2.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup2.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup2.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup2.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup2.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Kashmir Files (2022) - Starring: Vivek Agnihotri (dir.), Mithun Chakraborty, Anupam Kher
# 2 - Jai Bhim (2021) - Starring: T.J. Gnanavel (dir.), Suriya, Lijo Mol Jose
# 3 - Anbe Sivam (2003) - Starring: Sundar C. (dir.), Kamal Haasan, Madhavan
# 4 - Pariyerum Perumal (2018) - Starring: Mari Selvaraj (dir.), Kathir, Anandhi
# 5 - Golmaal (1979) - Starring: Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami
# 6 - Nayakan (1987) - Starring: Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan
# 7 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan
# 98 - Maheshinte Prathikaaram (2016) - Starring: Dileesh Pothan (dir.), Fahadh Faasil, Aparna Balamurali
# 99 - KGF: Chapter 1 (2018) - Starring: Prashanth Neel (dir.), Yash, Srinidhi Shetty
# 10 -  Rang De Basanti (2006) - Starring: Rakeysh Omprakash Mehra (dir.), Aamir Khan, Soha Ali Khan

# %%
#Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

page4 = requests.get("https://meesho.com/bags-ladies/pl/p7vbp")

# page content
soup4=BeautifulSoup(page4.content)

# scraping the product name
product_name = [] # creating empty list
for i in soup4.find_all('p',class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"): 
    product_name.append(i.text)

# scraping the product price   
price = []
for i in soup4.find_all('h5',class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"): 
    price.append(i.text)
    
# scraping the discount on product   
discount = []
for i in soup4.find_all('span',class_="Text__StyledText-sc-oo0kvp-0 lnonyH"): 
    discount.append(i.text) # printing last 7 characters only

    # Creating data frame 
import pandas as pd
df = pd.DataFrame({'Product_Name':product_name,'Price':price,'Discount':discount})
df
page4 = requests.get("https://meesho.com/bags-ladies/pl/p7vbp")
page4 = requests.get("https://meesho.com/bags-ladies/pl/p7vbp")

# page content
soup4=BeautifulSoup(page4.content)

# scraping the product name
product_name = [] # creating empty list
for i in soup4.find_all('p',class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"): 
    product_name.append(i.text)

# scraping the product price   
price = []
for i in soup4.find_all('h5',class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"): 
    price.append(i.text)
    
# scraping the discount on product   
discount = []
for i in soup4.find_all('span',class_="Text__StyledText-sc-oo0kvp-0 lnonyH"): 
    discount.append(i.text) # printing last 7 characters only

    # Creating data frame 
import pandas as pd
df = pd.DataFrame({'Product_Name':product_name,'Price':price,'Discount':discount})
df
# Out:
#                                          Product_Name Price Discount
# 0                   Trendy Fashionable Women Handbags  ₹330  23% off
# 1                          Elite Fancy Women Handbags  ₹270  27% off
# 2                      Elegant Classy Women Handbags   ₹269  27% off
# 3                      Elite Versatile Women Handbags  ₹188  30% off
# 4   Fashionable Trendy Women's Waterproof Cosmetic...  ₹195  30% off
# 5                   Elegant Attractive Women Handbags  ₹140  30% off
# 6                   Classic Attractive Women Handbags  ₹157  30% off
# 7                     Trendy Versatile Women Handbags  ₹280  26% off
# 8                    Classic Versatile Women Handbags  ₹171  30% off
# 9                       Trendy Stylish Women Handbags  ₹189  30% off
# 10                 Voguish Fashionable Women Handbags  ₹241  29% off
# 11                     Classic Stylish Women Handbags  ₹189  30% off
# 12                  Ravishing Alluring Women Handbags  ₹130  30% off
# 13                    Voguish Alluring Women Handbags  ₹496  17% off
# 14                   Ravishing Stylish Women Handbags  ₹186  30% off
# 15                   Elite Fashionable Women Handbags  ₹299  25% off
# 16                     Gorgeous Classy Women Handbags  ₹190  30% off
# 17                      Elite Alluring Women Handbags  ₹344  23% off
# 18                 Classic Fashionable Women Handbags  ₹282  26% off
# 19         Elegant Fancy Women'S Pu Leather Hand Bags  ₹170  30% off

# %%
 #Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

#i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
page5 = requests.get(url)
# see content in page5
soup5 = BeautifulSoup(page5.content)
#scrape team names
team = soup5.find_all("span",class_='u-hide-phablet')
team_name = []
for i in team:
    team_name.append(i.text)
matches = [] #empty list
points = [] #empty list
ratings = [] #empty list
new_list = [] #empty list

for i in soup5.find_all("td",class_='rankings-block__banner--matches'): # first place team number of matches
    matches.append(i.text)
for i in soup5.find_all("td",class_='rankings-block__banner--points'):# first place team points
    points.append(i.text)
for i in soup5.find_all("td",class_='rankings-block__banner--rating u-text-right'):# first place team ratings
    ratings.append(i.text.replace("\n",""))
for i in soup5.find_all("td",class_='table-body__cell u-center-text'):# other teams number of matches and points
    new_list.append(i.text)
for i in range(0,len(new_list)-1,2):
    matches.append(new_list[i]) # other teams matches
    points.append(new_list[i+1]) # other teams points
for i in soup5.find_all("td",class_='table-body__cell u-text-right rating'):# other teams ratings
    ratings.append(i.text)
    
# Make data frame of top 10 ICC teams
icc=pd.DataFrame({})
icc['Team_name']=team_name[:10]
icc['Matches']=matches[:10]
icc['Points']=points[:10]
icc['Ratings']=ratings[:10]
icc
# Out:
#       Team_name Matches Points  \
# 0   New Zealand      17  2,054
# 1       England      32  3,793
# 2     Australia      28  3,244
# 3         India      38  4,162
# 4  South Africa      28  2,943
# 5      Pakistan      27  2,524
# 6    Bangladesh      33  2,988
# 7     Sri Lanka      35  2,835
# 8   West Indies      36  2,788
# 9   Afghanistan      23  1,562
#
#                                              Ratings
# 0                              121               ...
# 1                                                119
# 2                                                116
# 3                                                110
# 4                                                105
# 5                                                 93
# 6                                                 91
# 7                                                 81
# 8                                                 77
# 9                                                 68

# %%
#Top 10 ODI Batsmen in men along with the records of their team and rating.
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
page6 = requests.get(url)
# see content in page6
soup6 = BeautifulSoup(page6.content)
players = [] #empty list
team_name = [] #empty list
rating = [] #empty list

for i in soup6.find_all("div",class_='rankings-block__banner--name-large'): # first place player name
    players.append(i.text)
for i in soup6.find_all("div",class_='rankings-block__banner--nationality'): # first place player team name
    team_name.append(i.text.replace("\n",""))
for i in soup6.find_all("div",class_='rankings-block__banner--rating'): # first place player rating
    rating.append(i.text)
for i in soup6.find_all("td",class_='table-body__cell rankings-table__name name'):# players name
    for j in i.find_all('a'):
        players.append(j.text)
for i in soup6.find_all("span",class_='table-body__logo-text'): # players team name
    team_name.append(i.text)
for i in soup6.find_all("td",class_='table-body__cell rating'): # players rating
    rating.append(i.text)
# Make data frame of top 10 ICC Batsmen
Batsmen=pd.DataFrame({})
Batsmen['Player']=players[:10]
Batsmen['Team']=team_name[:10]
Batsmen['Rating']=rating[:10]
Batsmen
# Out:
#                   Player                     Team Rating
# 0             Babar Azam  PAK                        873
# 1            Virat Kohli                      IND    811
# 2           Rohit Sharma                      IND    791
# 3        Quinton de Kock                       SA    783
# 4            Aaron Finch                      AUS    779
# 5         Jonny Bairstow                      ENG    775
# 6           David Warner                      AUS    762
# 7  Rassie van der Dussen                       SA    750
# 8           Fakhar Zaman                      PAK    741
# 9               Joe Root                      ENG    740

# %%
#Top 10 ODI bowlers along with the records of their team and rating
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
page7 = requests.get(url)

# see content in page7
soup7 = BeautifulSoup(page7.content)

players = [] #empty list
team_name = [] #empty list  
rating = [] #empty list 

for i in soup7.find_all("div",class_='rankings-block__banner--name-large'): # first place player name
    players.append(i.text)
for i in soup7.find_all("div",class_='rankings-block__banner--nationality'): # first place player team name
    team_name.append(i.text.replace("\n",""))
for i in soup7.find_all("div",class_='rankings-block__banner--rating'): # first place player rating
    rating.append(i.text)
for i in soup7.find_all("td",class_='table-body__cell rankings-table__name name'):# players name
    for j in i.find_all('a'):
        players.append(j.text)
for i in soup7.find_all("span",class_='table-body__logo-text'): # players team name
    team_name.append(i.text)
for i in soup7.find_all("td",class_='table-body__cell rating'): # players rating
    rating.append(i.text)
# Make data frame of top 10 ICC bowlers
bowlers=pd.DataFrame({})
bowlers['Player']=players[:10]
bowlers['Team']=team_name[:10]
bowlers['Rating']=rating[:10]
bowlers
# Out:
#              Player                    Team Rating
# 0       Trent Boult  NZ                        737
# 1    Josh Hazlewood                     AUS    709
# 2      Chris Woakes                     ENG    700
# 3        Matt Henry                      NZ    691
# 4  Mujeeb Ur Rahman                     AFG    681
# 5    Jasprit Bumrah                     IND    679
# 6      Mehedi Hasan                     BAN    675
# 7    Mitchell Starc                     AUS    652
# 8       Rashid Khan                     AFG    650
# 9      Andy McBrine                     IRE    646

# %%
#Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
page8 = requests.get(url)
#see content in page8
soup8 = BeautifulSoup(page8.content)
#scrape team names
womens_team = soup8.find_all("span",class_='u-hide-phablet')
womens_team_name = []
for i in womens_team:
    womens_team_name.append(i.text)
womens_matches = [] #empty list
womens_points = [] #empty list
womens_ratings = [] #empty list
womens_new_list = [] #empty list
for i in soup8.find_all("td",class_='rankings-block__banner--matches'): # first place team number of matches
    womens_matches.append(i.text)
for i in soup8.find_all("td",class_='rankings-block__banner--points'):# first place team points
    womens_points.append(i.text)
for i in soup8.find_all("td",class_='rankings-block__banner--rating u-text-right'):# first place team ratings
    womens_ratings.append(i.text.replace("\n",""))
for i in soup8.find_all("td",class_='table-body__cell u-center-text'):# other teams number of matches and points
    womens_new_list.append(i.text)
for i in range(0,len(womens_new_list)-1,2):
    womens_matches.append(womens_new_list[i]) # other teams matches
    womens_points.append(womens_new_list[i+1]) # other teams points
for i in soup8.find_all("td",class_='table-body__cell u-text-right rating'):# other teams number of matches and ratings
    womens_ratings.append(i.text)
# Make data frame of top 10 ICC teams
womens_icc=pd.DataFrame({})
womens_icc['Team_name']=womens_team_name[:10]
womens_icc['Matches']=womens_matches[:10]
womens_icc['Points']=womens_points[:10]
womens_icc['Ratings']=womens_ratings[:10]
womens_icc
# Out:
#       Team_name Matches Points  \
# 0     Australia      20  3,263
# 1  South Africa      21  2,580
# 2       England      21  2,474
# 3         India      22  2,221
# 4   New Zealand      24  2,342
# 5    Bangladesh       5    475
# 6   West Indies      21  1,801
# 7      Pakistan      19  1,304
# 8       Ireland       5    240
# 9     Sri Lanka       5    233
#
#                                              Ratings
# 0                              163               ...
# 1                                                123
# 2                                                118
# 3                                                101
# 4                                                 98
# 5                                                 95
# 6                                                 86
# 7                                                 69
# 8                                                 48
# 9                                                 47

# %%
#Top 10 women’s ODI players along with the records of their team and rating.
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
page9 = requests.get(url)
# see content in page9
soup9 = BeautifulSoup(page9.content)
players = [] #empty list
team_name = [] #empty list
rating = [] #empty list

for i in soup9.find_all("div",class_='rankings-block__banner--name-large'): # first place player name
    players.append(i.text)
for i in soup9.find_all("div",class_='rankings-block__banner--nationality'): # first place player team name
    team_name.append(i.text.replace("\n",""))
for i in soup9.find_all("div",class_='rankings-block__banner--rating'): # first place player rating
    rating.append(i.text)
for i in soup9.find_all("td",class_='table-body__cell rankings-table__name name'):# players name
    for j in i.find_all('a'):
        players.append(j.text)
for i in soup9.find_all("span",class_='table-body__logo-text'): # players team name
    team_name.append(i.text)
for i in soup9.find_all("td",class_='table-body__cell rating'): # players rating
    rating.append(i.text)
# Make data frame of top 10 Women's ODI Batting Rankings
top_players=pd.DataFrame({})
top_players['Player']=players[:10]
top_players['Team']=team_name[:10]
top_players['Rating']=rating[:10]
top_players
# Out:
#               Player                     Team Rating
# 0       Alyssa Healy  AUS                        742
# 1        Meg Lanning                      AUS    727
# 2     Tammy Beaumont                      ENG    725
# 3        Mithali Raj                      IND    718
# 4        Beth Mooney                      AUS    713
# 5     Natalie Sciver                      ENG    711
# 6     Rachael Haynes                      AUS    705
# 7  Amy Satterthwaite                       NZ    694
# 8        Lizelle Lee                       SA    688
# 9    Smriti Mandhana                      IND    670

# %%
#Top 10 women’s ODI all-rounder along with the records of their team and rating.
#send get request to the webpage server to get the source code of the page
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"
page10 = requests.get(url)

# see content in page10
soup10 = BeautifulSoup(page10.content)

players = [] #empty list
team_name = [] #empty list  
rating = [] #empty list 

for i in soup10.find_all("div",class_='rankings-block__banner--name-large'): # first place player name
    players.append(i.text)
for i in soup10.find_all("div",class_='rankings-block__banner--nationality'): # first place player team name
    team_name.append(i.text.replace("\n",""))
for i in soup10.find_all("div",class_='rankings-block__banner--rating'): # first place player rating
    rating.append(i.text)
for i in soup10.find_all("td",class_='table-body__cell rankings-table__name name'):# players name
    for j in i.find_all('a'):
        players.append(j.text)
for i in soup10.find_all("span",class_='table-body__logo-text'): # players team name
    team_name.append(i.text)
for i in soup10.find_all("td",class_='table-body__cell rating'): # players rating
    rating.append(i.text)
# Make data frame of top 10 ICC Women's ODI All-Rounder Rankings
all_rounder=pd.DataFrame({})
all_rounder['Player']=players[:10]
all_rounder['Team']=team_name[:10]
all_rounder['Rating']=rating[:10]
all_rounder
# Out:
#              Player                     Team Rating
# 0      Ellyse Perry  AUS                        435
# 1    Natalie Sciver                      ENG    380
# 2    Marizanne Kapp                       SA    338
# 3   Hayley Matthews                       WI    333
# 4       Amelia Kerr                       NZ    325
# 5     Deepti Sharma                      IND    310
# 6   Katherine Brunt                      ENG    279
# 7     Jess Jonassen                      AUS    261
# 8  Ashleigh Gardner                      AUS    246
# 9   Stafanie Taylor                       WI    246

# %%
#Write a python program to scrape house details from mentioned URL. It should include house title, location, area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar, Rajaji Nagar.
#send get request to the webpage server to get the source code of the page
url = "https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...&radius=2.0&city=bangalore&locality=Rajajinagar,&locality=Jayanagar,&locality=Indiranagar"
page14 = requests.get(url)
# see content in page14
soup14 = BeautifulSoup(page14.content)

house = []  #empty list
location = []  #empty list
Area = []  #empty list
EMI = []   #empty list
price = []   #empty list

#scrape house title 
houses = soup14.find_all("h2", class_="heading-6 font-semi-bold nb__25Cl7")
for i in houses:
    house.append(i.text)
    
#scrape house location     
loc = soup14.find_all('div',class_="nb__1EwQz")
for i in loc:
    location.append(i.text)
    
#scrape house location     
area = soup14.find_all('div',class_="nb__FfHqA")
for i in area:
    Area.append(i.text)
    

full_info = []
detail = soup14.find_all('div',class_="font-semi-bold heading-6")
for i in detail:
    full_info.append(i.text)

#EMI
for i in range(1,len(full_info),3):
    EMI.append(full_info[i])

# price
for i in range(2,len(full_info),3):
    price.append(full_info[i])

# Make data frame
nobroker=pd.DataFrame({})
nobroker['House']=house
nobroker['Area']=Area
nobroker['location']=location
nobroker['EMI']=EMI
nobroker['price']=price
nobroker
# Out:
#    House  Area  location               EMI        price
# 0    NaN   NaN       NaN     ₹44,705/Month     ₹78 Lacs
# 1    NaN   NaN       NaN  ₹1.55 Lacs/Month  ₹2.7 Crores
# 2    NaN   NaN       NaN     ₹91,703/Month  ₹1.6 Crores
# 3    NaN   NaN       NaN     ₹74,508/Month  ₹1.3 Crores
# 4    NaN   NaN       NaN     ₹63,045/Month  ₹1.1 Crores

# %%
#Write a python program to scrape mentioned details from ‘https://www.dineout.co.in/delhi-restaurants/buffetspecial’ : i) Restaurant name ii) Cuisine iii) Location iv) Ratings v) Image url
# Importing Libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
#send get request to the webpage server to get the source code of the page
page = requests.get("https://www.dineout.co.in/delhi-restaurants/buffet-special")
# page content
soup=BeautifulSoup(page.content)
name=[]
for i in soup.find_all("div", class_="restnt-info cursor"):
    name.append(i.text)
location=[]
for i in soup.find_all("div", class_="restnt-loc ellipsis"):
    location.append(i.text)

price = []
cuisine = []
for i in soup.find_all("span", class_="double-line-ellipsis"):
    price.append(i.text.split('|')[0])
    cuisine.append(i.text.split('|')[1])

rating=[]
for i in soup.find_all("div", class_="restnt-rating rating-3"):
    rating.append(i.text)
for i in soup.find_all("div", class_="restnt-rating rating-4"):
    rating.append(i.text)

images = []
for i in soup.find_all("img", class_="no-img"):
    images.append(i['data-src'])

print(len(name), len(location), len(price), len(cuisine), len(rating), len(images))

# Make data frame
DineOut=pd.DataFrame({})
DineOut['Restaurant Name']=name
DineOut['Location']=location
DineOut['Price']=price 
DineOut['Cuisine']=cuisine  
DineOut['Rating']=rating  
DineOut['IMAGES']=images
DineOut
# Out:
# 13 13 13 13 13 13
#                                       Restaurant Name  \
# 0       Castle BarbequeConnaught Place, Central Delhi
# 1   Jungle Jamboree3CS Mall,Lajpat Nagar - 3, Sout...
# 2   Cafe KnoshThe Leela Ambience Convention Hotel,...
# 3   Castle BarbequePacific Mall,Tagore Garden, Wes...
# 4   The Barbeque CompanyGardens Galleria,Sector 38...
# 5     India GrillHilton Garden Inn,Saket, South Delhi
# 6   Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 7   The Monarch - Bar Be Que VillageIndirapuram Ha...
# 8   World CafeVibe by The Lalit Traveller,Sector 3...
# 9   Indian Grill RoomSuncity Business Tower,Golf C...
# 10                Mad 4 Bar B QueSector 29, Faridabad
# 11                          Barbeque 29NIT, Faridabad
# 12  GlasshouseDoubleTree By Hilton Gurugram Baani ...
#
#                                              Location  \
# 0                      Connaught Place, Central Delhi
# 1              3CS Mall,Lajpat Nagar - 3, South Delhi
# 2   The Leela Ambience Convention Hotel,Shahdara, ...
# 3              Pacific Mall,Tagore Garden, West Delhi
# 4                  Gardens Galleria,Sector 38A, Noida
# 5                Hilton Garden Inn,Saket, South Delhi
# 6      Taurus Sarovar Portico,Mahipalpur, South Delhi
# 7   Indirapuram Habitat Centre,Indirapuram, Ghaziabad
# 8    Vibe by The Lalit Traveller,Sector 35, Faridabad
# 9    Suncity Business Tower,Golf Course Road, Gurgaon
# 10                               Sector 29, Faridabad
# 11                                     NIT, Faridabad
# 12  DoubleTree By Hilton Gurugram Baani Square,Sec...
#
#                       Price                                      Cuisine  \
# 0   ₹ 2,000 for 2 (approx)                         North Indian, Chinese
# 1   ₹ 1,400 for 2 (approx)                  North Indian, Asian, Italian
# 2   ₹ 3,000 for 2 (approx)                          Italian, Continental
# 3   ₹ 2,000 for 2 (approx)                         Chinese, North Indian
# 4   ₹ 1,700 for 2 (approx)                         North Indian, Chinese
# 5   ₹ 2,400 for 2 (approx)                         North Indian, Italian
# 6   ₹ 1,800 for 2 (approx)                                  North Indian
# 7   ₹ 1,900 for 2 (approx)                         North Indian, Chinese
# 8   ₹ 1,800 for 2 (approx)            North Indian, Chinese, Continental
# 9   ₹ 2,000 for 2 (approx)                         North Indian, Mughlai
# 10    ₹ 800 for 2 (approx)                         North Indian, Mughlai
# 11  ₹ 1,500 for 2 (approx)    North Indian, Mughlai, Desserts, Beverages
# 12  ₹ 3,400 for 2 (approx)         European, Italian, Asian, Continental
#
#    Rating                                             IMAGES
# 0     3.5  https://im1.dineout.co.in/images/uploads/resta...
# 1     3.9  https://im1.dineout.co.in/images/uploads/resta...
# 2     4.3  https://im1.dineout.co.in/images/uploads/resta...
# 3     3.9  https://im1.dineout.co.in/images/uploads/resta...
# 4       4  https://im1.dineout.co.in/images/uploads/resta...
# 5     3.9  https://im1.dineout.co.in/images/uploads/resta...
# 6     3.7  https://im1.dineout.co.in/images/uploads/resta...
# 7     3.8  https://im1.dineout.co.in/images/uploads/resta...
# 8     4.2  https://im1.dineout.co.in/images/uploads/resta...
# 9     4.3  https://im1.dineout.co.in/images/uploads/resta...
# 10    3.6  https://im1.dineout.co.in/images/uploads/resta...
# 11    4.2  https://im1.dineout.co.in/images/uploads/resta...
# 12    4.1  https://im1.dineout.co.in/images/uploads/resta...

# %%
#Write a python program to scrape first 10 product details which include product name , price , Image URL from https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

page = requests.get("https://www.bewakoof.com/women-tshirts?ga_q=tshirts")
page 

# page content
soup=BeautifulSoup(page.content)
# scraping the product name
product_name = [] # creating empty list
for i in soup.find_all('div',class_="productCardDetail")[:10]: 
    product_name.append(i.text)

# scraping the product price   
price = []
for i in soup.find_all('span',class_="discountedPriceText")[:10]: 
    price.append(i.text)
    
# scraping the image_url 
image_url = []
for i in soup.find_all('img',class_="productImgTag")[:10]: 
    image_url.append(i.get('src')) 
# checking the length 
print(len(product_name),len(price),len(image_url))

# Creating data frame 
import pandas as pd
df = pd.DataFrame({'Product_Name':product_name,'Price':price,'Image_url':image_url})
df
# Out:
# 10 10 10
#                                         Product_Name  Price  \
# 0  Powered By Coffee Half Sleeve Printed T-shirt₹...  ₹ 199
# 1  Bonjour Paris Half Sleeve Printed Pink T-Shirt...  ₹ 199
# 2  Chibi Harry Half Sleeve Printed T-shirt (HPL)₹...  ₹ 249
# 3  Stay Classy Minnie Half Sleeve T-Shirt (DL)₹ 2...  ₹ 249
# 4  Stay Away Panda Printed Half Sleeve Pink T-shi...  ₹ 249
# 5  Bugs On A Pocket Half Sleeve Printed T-Shirt(L...  ₹ 249
# 6  Goofy Mickey Pocket Half Sleeve Printed T-Shir...  ₹ 249
# 7  Nope Lazy Half Sleeve Printed T-shirt₹ 249799₹...  ₹ 249
# 8  Bonjour Paris Half Sleeve Printed Red T-Shirt₹...  ₹ 249
# 9  Climbing pocket panda Printed Half Sleeve T-sh...  ₹ 299
#
#                                            Image_url
# 0  https://images.bewakoof.com/t320/powered-by-co...
# 1  https://images.bewakoof.com/t320/bonjour-paris...
# 2  https://images.bewakoof.com/t320/chibi-harry-h...
# 3  https://images.bewakoof.com/t320/stay-classy-m...
# 4  https://images.bewakoof.com/t320/stay-away-pan...
# 5  https://images.bewakoof.com/t320/bugs-on-a-poc...
# 6  https://images.bewakoof.com/t320/goofy-mickey-...
# 7  https://images.bewakoof.com/t320/nope-lazy-wom...
# 8  https://images.bewakoof.com/t320/bonjour-paris...
# 9  https://images.bewakoof.com/t320/climbing-pock...
